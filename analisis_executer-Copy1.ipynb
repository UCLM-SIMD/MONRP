# %%
# Esta celda actúa sobre la libreta, y permite que se aproveche mejor el espacio.
from IPython.core.display import display, HTML
display(HTML("<style>.container{ width:95%}</style>"))
import sys
print(sys.executable) 
#import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
import seaborn as sns
from sklearn import preprocessing

from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
El codigo Python de este cuaderno está oculto para facilitar la lectura.
Para mostrar/ocultar el código, haz click <a href="javascript:code_toggle()">aquí.</a>.''')
# Out:
# <style>.container{ width:95%}</style>
# c:\users\48259328\appdata\local\programs\python\python38\python.exe
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# El codigo Python de este cuaderno está oculto para facilitar la lectura.
# Para mostrar/ocultar el código, haz click <a href="javascript:code_toggle()">aquí.</a>.

# %%
import pandas as pd
#df_alg=pd.read_csv('output/experimento_2datasets_2_10.csv')
df_alg=pd.read_csv('output/merged_output.txt')
display(df_alg.tail(5))
#display(df_alg.info())
convert_dict = {'Dataset': "string", 
                'Algorithm': "string",
                'Population Length': "int64",
                'Generations': "int64",
                'Selection Scheme': "string",
                'Selection Candidates': "int64",
                'Crossover Scheme': "string",
                'Crossover Probability': "float64",
                'Mutation Scheme': "string",
                'Mutation Probability': "float64",
                'Replacement Scheme': "string",
                'Time(s)': "float64",
                'AvgValue': "float64",
                'BestAvgValue': "float64",
                'BestGeneration': "int64",
                'HV': "float64",
                'Spread': "float64",
                'NumSolutions': "float64",
                'Spacing': "float64"
               } 
df_alg = df_alg.astype(convert_dict) 
display(df_alg.info())
# Out:
#         Dataset         Algorithm  Population Length  Generations  \
# 40271  dataset1  GeneticAlgorithm                 40          100
# 40272  dataset1  GeneticAlgorithm                 40          100
# 40273  dataset1  GeneticAlgorithm                 40          100
# 40274  dataset1  GeneticAlgorithm                 40          100
# 40275  dataset1  GeneticAlgorithm                 40          100
#
#       Selection Scheme  Selection Candidates Crossover Scheme  \
# 40271       tournament                     2         onepoint
# 40272       tournament                     2         onepoint
# 40273       tournament                     2         onepoint
# 40274       tournament                     2         onepoint
# 40275       tournament                     2         onepoint
#
#        Crossover Probability Mutation Scheme  Mutation Probability  \
# 40271                   0.85        flip1bit                   0.7
# 40272                   0.85        flip1bit                   0.7
# 40273                   0.85        flip1bit                   0.7
# 40274                   0.85        flip1bit                   0.7
# 40275                   0.85        flip1bit                   0.7
#
#       Replacement Scheme   Time(s)  AvgValue  BestAvgValue  BestGeneration  \
# 40271            elitism  3.401167  2.076807      3.370370              35
# 40272            elitism  3.455084  2.079762      3.609524              94
# 40273            elitism  3.388068  2.243167      3.315789              43
# 40274            elitism  3.420670  2.125318      3.988235              57
# 40275            elitism  3.399063  2.079453      3.684211              74
#
#        HV  Spread  NumSolutions  Spacing
# 40271 NaN     NaN           NaN      NaN
# 40272 NaN     NaN           NaN      NaN
# 40273 NaN     NaN           NaN      NaN
# 40274 NaN     NaN           NaN      NaN
# 40275 NaN     NaN           NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40276 entries, 0 to 40275
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Dataset                40276 non-null  string
#  1   Algorithm              40276 non-null  string
#  2   Population Length      40276 non-null  int64
#  3   Generations            40276 non-null  int64
#  4   Selection Scheme       40276 non-null  string
#  5   Selection Candidates   40276 non-null  int64
#  6   Crossover Scheme       40276 non-null  string
#  7   Crossover Probability  40276 non-null  float64
#  8   Mutation Scheme        40276 non-null  string
#  9   Mutation Probability   40276 non-null  float64
#  10  Replacement Scheme     40276 non-null  string
#  11  Time(s)                40276 non-null  float64
#  12  AvgValue               40276 non-null  float64
#  13  BestAvgValue           40276 non-null  float64
#  14  BestGeneration         40276 non-null  int64
#  15  HV                     30196 non-null  float64
#  16  Spread                 30196 non-null  float64
#  17  NumSolutions           30196 non-null  float64
#  18  Spacing                30196 non-null  float64
# dtypes: float64(9), int64(4), string(6)
# memory usage: 5.8 MB
# None

# %%
summary=(
df_alg.groupby(['Dataset','Algorithm','Population Length', 'Generations'])
    [['Time(s)', 'HV', 'Spread',"AvgValue","BestAvgValue","BestGeneration","NumSolutions","Spacing"]]
    .agg(['mean'])
    .reset_index()
)
summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Dataset, )             54 non-null     object
#  1   (Algorithm, )           54 non-null     object
#  2   (Population Length, )   54 non-null     int64
#  3   (Generations, )         54 non-null     int64
#  4   (Time(s), mean)         54 non-null     float64
#  5   (HV, mean)              36 non-null     float64
#  6   (Spread, mean)          36 non-null     float64
#  7   (AvgValue, mean)        54 non-null     float64
#  8   (BestAvgValue, mean)    54 non-null     float64
#  9   (BestGeneration, mean)  54 non-null     float64
#  10  (NumSolutions, mean)    36 non-null     float64
#  11  (Spacing, mean)         36 non-null     float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 5.2+ KB

# %% [markdown]
# ---
# # Dataset 1

# %% [markdown]
# ## Dataset 1-Genetic analysis

# %%
df_genetic=summary[(summary['Dataset']=='dataset1') & (summary['Algorithm']=='GeneticAlgorithm')]
df_genetic
# Out:
#     Dataset         Algorithm Population Length Generations   Time(s)   HV  \
#                                                                  mean mean
# 0  dataset1  GeneticAlgorithm                20         100  1.666222  NaN
# 1  dataset1  GeneticAlgorithm                20         200  3.321819  NaN
# 2  dataset1  GeneticAlgorithm                20         300  4.972341  NaN
# 3  dataset1  GeneticAlgorithm                30         100  2.450507  NaN
# 4  dataset1  GeneticAlgorithm                30         200  4.880151  NaN
# 5  dataset1  GeneticAlgorithm                30         300  7.300586  NaN
# 6  dataset1  GeneticAlgorithm                40         100  3.239100  NaN
# 7  dataset1  GeneticAlgorithm                40         200  6.428888  NaN
# 8  dataset1  GeneticAlgorithm                40         300  9.635389  NaN
#
#   Spread  AvgValue BestAvgValue BestGeneration NumSolutions Spacing
#     mean      mean         mean           mean         mean    mean
# 0    NaN  2.189716     3.334135      50.030357          NaN     NaN
# 1    NaN  2.201184     3.406149     101.841071          NaN     NaN
# 2    NaN  2.212473     3.465396     149.896429          NaN     NaN
# 3    NaN  2.184252     3.549123      51.973214          NaN     NaN
# 4    NaN  2.186798     3.508428      97.410714          NaN     NaN
# 5    NaN  2.194682     3.575204     154.942857          NaN     NaN
# 6    NaN  2.179416     3.645233      47.830357          NaN     NaN
# 7    NaN  2.180792     3.599581     100.691071          NaN     NaN
# 8    NaN  2.184825     3.642823     155.376786          NaN     NaN

# %% [markdown]
# ## Dataset 1-GeneticNDS analysis

# %%
df_geneticnds1=df_alg[(df_alg['Replacement Scheme']=='elitism')]
df_geneticnds1=(
    df_geneticnds1.groupby(['Dataset','Algorithm','Population Length', 'Generations'])\
    [['Time(s)', 'HV', 'Spread',"AvgValue","BestAvgValue","BestGeneration","NumSolutions","Spacing"]]\
    .agg(['mean'])\
    .reset_index()\
)
df_geneticnds1=df_geneticnds1[(df_geneticnds1['Dataset']=='dataset1') & (df_geneticnds1['Algorithm']=='GeneticNDSAlgorithm')]
display(df_geneticnds1)
# Out:
#      Dataset            Algorithm Population Length Generations     Time(s)  \
#                                                                        mean
# 9   dataset1  GeneticNDSAlgorithm                20         100   28.520164
# 10  dataset1  GeneticNDSAlgorithm                20         200   97.199433
# 11  dataset1  GeneticNDSAlgorithm                20         300  476.520628
# 12  dataset1  GeneticNDSAlgorithm                30         100   22.946351
# 13  dataset1  GeneticNDSAlgorithm                30         200  201.545998
# 14  dataset1  GeneticNDSAlgorithm                30         300  652.370964
# 15  dataset1  GeneticNDSAlgorithm                40         100   41.560777
# 16  dataset1  GeneticNDSAlgorithm                40         200  327.888269
# 17  dataset1  GeneticNDSAlgorithm                40         300  355.248750
#
#               HV    Spread  AvgValue BestAvgValue BestGeneration NumSolutions  \
#             mean      mean      mean         mean           mean         mean
# 9    9290.160000  0.783097  3.951127     5.828331      50.030357    27.628571
# 10   9894.049286  0.792710  4.122454     6.056102     101.841071    30.517857
# 11  10320.929643  0.798919  4.248763     6.475565     149.896429    32.407143
# 12   9623.192500  0.769097  3.998297     5.901074      51.973214    29.201786
# 13  10182.422500  0.786433  4.181968     6.313068      97.410714    32.419643
# 14  10806.240357  0.790579  4.306319     6.678681     154.942857    33.608929
# 15  10103.555714  0.766504  4.071547     6.053655      47.830357    30.237500
# 16  10607.770714  0.789411  4.255009     6.434962     100.691071    34.023214
# 17  11108.509286  0.806263  4.370738     6.653171     155.376786    35.689286
#
#      Spacing
#         mean
# 9   0.300530
# 10  0.301669
# 11  0.304734
# 12  0.316113
# 13  0.312580
# 14  0.321849
# 15  0.313467
# 16  0.320528
# 17  0.324408

# %%
df_geneticnds1=df_alg[(df_alg['Replacement Scheme']=='elitismnds')]
df_geneticnds1=(
    df_geneticnds1.groupby(['Dataset','Algorithm','Population Length', 'Generations'])\
    [['Time(s)', 'HV', 'Spread',"AvgValue","BestAvgValue","BestGeneration","NumSolutions","Spacing"]]\
    .agg(['mean'])\
    .reset_index()\
)
df_geneticnds1=df_geneticnds1[(df_geneticnds1['Dataset']=='dataset1') & (df_geneticnds1['Algorithm']=='GeneticNDSAlgorithm')]
display(df_geneticnds1)
# Out:
#     Dataset            Algorithm Population Length Generations      Time(s)  \
#                                                                        mean
# 0  dataset1  GeneticNDSAlgorithm                20         100    69.208987
# 1  dataset1  GeneticNDSAlgorithm                20         200   951.223135
# 2  dataset1  GeneticNDSAlgorithm                20         300  2905.088007
# 3  dataset1  GeneticNDSAlgorithm                30         100    77.670828
# 4  dataset1  GeneticNDSAlgorithm                30         200   876.508221
# 5  dataset1  GeneticNDSAlgorithm                30         300  2810.765086
# 6  dataset1  GeneticNDSAlgorithm                40         100   120.088480
# 7  dataset1  GeneticNDSAlgorithm                40         200   649.393398
# 8  dataset1  GeneticNDSAlgorithm                40         300  2323.117349
#
#              HV    Spread  AvgValue BestAvgValue BestGeneration NumSolutions  \
#            mean      mean      mean         mean           mean         mean
# 0   9021.657857  0.841957  4.123073     5.228356      38.407143    25.055357
# 1   9623.046429  0.865376  4.406639     5.492667      74.396429    26.894643
# 2  10062.033571  0.880594  4.576020     5.640672     108.433929    28.508929
# 3   9506.112500  0.830191  4.177446     5.349200      39.091071    26.698214
# 4   9831.357143  0.857302  4.454576     5.642560      75.358929    29.058929
# 5  10507.956071  0.874603  4.612826     5.687255     107.178571    29.705357
# 6   9883.415000  0.834853  4.241549     5.439659      36.053571    27.955357
# 7  10305.688929  0.861937  4.506096     5.661903      69.198214    30.516071
# 8  10734.884643  0.868003  4.604524     5.751789     109.832143    31.710714
#
#     Spacing
#        mean
# 0  0.294246
# 1  0.302507
# 2  0.300195
# 3  0.314345
# 4  0.311008
# 5  0.313780
# 6  0.314655
# 7  0.311652
# 8  0.313662

# %% [markdown]
# ## Dataset 1-NSGA-II analysis

# %%
df_nsgaii=summary[(summary['Dataset']=='dataset1') & (summary['Algorithm']=='NSGAIIAlgorithm')]
df_nsgaii
# Out:
#      Dataset        Algorithm Population Length Generations      Time(s)  \
#                                                                     mean
# 18  dataset1  NSGAIIAlgorithm                20         100     8.494412
# 19  dataset1  NSGAIIAlgorithm                20         200    16.781261
# 20  dataset1  NSGAIIAlgorithm                20         300    25.110456
# 21  dataset1  NSGAIIAlgorithm                30         100    15.856232
# 22  dataset1  NSGAIIAlgorithm                30         200    31.184147
# 23  dataset1  NSGAIIAlgorithm                30         300  1094.181763
# 24  dataset1  NSGAIIAlgorithm                40         100    25.201351
# 25  dataset1  NSGAIIAlgorithm                40         200    49.140220
# 26  dataset1  NSGAIIAlgorithm                40         300  1305.592318
#
#               HV    Spread  AvgValue BestAvgValue BestGeneration NumSolutions  \
#             mean      mean      mean         mean           mean         mean
# 18   9423.913571  0.867730  3.480371     5.537133      58.035714    17.878571
# 19  10818.169286  0.868144  3.601214     6.050987     116.608929    18.019643
# 20  11471.643929  0.867653  3.628699     6.237787     169.589286    18.017857
# 21   9928.117143  0.899543  3.647423     6.011618      59.475000    23.476786
# 22  11328.386786  0.901475  3.800592     6.574211     116.421429    24.680357
# 23  11999.891786  0.902406  3.858301     6.866725     164.110714    25.164286
# 24  10367.272500  0.916909  3.724420     6.245522      59.141071    26.966071
# 25  11548.022143  0.920096  3.897005     6.833894     111.992857    28.294643
# 26  12266.417500  0.922011  3.972026     7.103189     158.691071    28.887500
#
#      Spacing
#         mean
# 18  0.319955
# 19  0.346014
# 20  0.355303
# 21  0.324792
# 22  0.348061
# 23  0.356715
# 24  0.330629
# 25  0.356859
# 26  0.373686

# %% [markdown]
# ---
# # Dataset 2

# %% [markdown]
# ## Dataset 2-Genetic analysis

# %%
df_genetic2=summary[(summary['Dataset']=='dataset2') & (summary['Algorithm']=='GeneticAlgorithm')]
df_genetic2
# Out:
#      Dataset         Algorithm Population Length Generations     Time(s)   HV  \
#                                                                     mean mean
# 27  dataset2  GeneticAlgorithm                20         100    7.197103  NaN
# 28  dataset2  GeneticAlgorithm                20         200   14.348851  NaN
# 29  dataset2  GeneticAlgorithm                20         300   21.407090  NaN
# 30  dataset2  GeneticAlgorithm                30         100   10.617972  NaN
# 31  dataset2  GeneticAlgorithm                30         200   21.105845  NaN
# 32  dataset2  GeneticAlgorithm                30         300  369.092593  NaN
# 33  dataset2  GeneticAlgorithm                40         100  858.510560  NaN
# 34  dataset2  GeneticAlgorithm                40         200   28.043106  NaN
# 35  dataset2  GeneticAlgorithm                40         300   41.937952  NaN
#
#    Spread  AvgValue BestAvgValue BestGeneration NumSolutions Spacing
#      mean      mean         mean           mean         mean    mean
# 27    NaN  0.554493     0.630724      51.830357          NaN     NaN
# 28    NaN  0.554378     0.632790     102.896429          NaN     NaN
# 29    NaN  0.554654     0.634232     158.989286          NaN     NaN
# 30    NaN  0.553800     0.638012      51.660714          NaN     NaN
# 31    NaN  0.554057     0.640489     104.037500          NaN     NaN
# 32    NaN  0.554278     0.640019     157.432143          NaN     NaN
# 33    NaN  0.552883     0.641092      54.073214          NaN     NaN
# 34    NaN  0.553258     0.645070     109.167857          NaN     NaN
# 35    NaN  0.553653     0.645284     158.926786          NaN     NaN

# %% [markdown]
# ## Dataset 2-GeneticNDS analysis

# %%
df_geneticnds2=df_alg[(df_alg['Replacement Scheme']=='elitism')]
df_geneticnds2=(
    df_geneticnds2.groupby(['Dataset','Algorithm','Population Length', 'Generations'])\
    [['Time(s)', 'HV', 'Spread',"AvgValue","BestAvgValue","BestGeneration","NumSolutions","Spacing"]]\
    .agg(['mean'])\
    .reset_index()\
)
df_geneticnds2=df_geneticnds2[(df_geneticnds2['Dataset']=='dataset2') & (df_geneticnds2['Algorithm']=='GeneticNDSAlgorithm')]
display(df_geneticnds2)
# Out:
#      Dataset            Algorithm Population Length Generations      Time(s)  \
#                                                                         mean
# 36  dataset2  GeneticNDSAlgorithm                20         100   318.331456
# 37  dataset2  GeneticNDSAlgorithm                20         200  1408.764216
# 38  dataset2  GeneticNDSAlgorithm                20         300  3012.774507
# 39  dataset2  GeneticNDSAlgorithm                30         100  1539.567800
# 40  dataset2  GeneticNDSAlgorithm                30         200  1735.403960
# 41  dataset2  GeneticNDSAlgorithm                30         300  3205.590620
# 42  dataset2  GeneticNDSAlgorithm                40         100   222.454808
# 43  dataset2  GeneticNDSAlgorithm                40         200  1635.034303
# 44  dataset2  GeneticNDSAlgorithm                40         300  3303.957335
#
#                HV    Spread  AvgValue BestAvgValue BestGeneration  \
#              mean      mean      mean         mean           mean
# 36   81859.933214  0.815734  0.659504     0.717799      51.830357
# 37   88701.391071  0.837266  0.668649     0.728286     102.896429
# 38   93092.811111  0.848364  0.673284     0.736375     159.068100
# 39   87857.705357  0.810130  0.661676     0.726465      51.660714
# 40   96787.396071  0.834725  0.671431     0.733788     104.037500
# 41   99090.577617  0.833943  0.677072     0.742989     156.893502
# 42   88666.968929  0.813882  0.664604     0.728669      54.073214
# 43   98568.610714  0.827212  0.672910     0.741890     109.167857
# 44  102590.566906  0.831423  0.679064     0.754212     159.438849
#
#    NumSolutions   Spacing
#            mean      mean
# 36    36.275000  0.113570
# 37    40.610714  0.114393
# 38    42.234767  0.113845
# 39    38.844643  0.116018
# 40    43.455357  0.115342
# 41    45.462094  0.120189
# 42    39.394643  0.117878
# 43    43.971429  0.121460
# 44    47.000000  0.122927

# %%
df_geneticnds2=df_alg[(df_alg['Replacement Scheme']=='elitismnds')]
df_geneticnds2=(
    df_geneticnds2.groupby(['Dataset','Algorithm','Population Length', 'Generations'])\
    [['Time(s)', 'HV', 'Spread',"AvgValue","BestAvgValue","BestGeneration","NumSolutions","Spacing"]]\
    .agg(['mean'])\
    .reset_index()\
)
df_geneticnds2=df_geneticnds2[(df_geneticnds2['Dataset']=='dataset2') & (df_geneticnds2['Algorithm']=='GeneticNDSAlgorithm')]
df_geneticnds2
# Out:
#      Dataset            Algorithm Population Length Generations      Time(s)  \
#                                                                         mean
# 9   dataset2  GeneticNDSAlgorithm                20         100   562.532637
# 10  dataset2  GeneticNDSAlgorithm                20         200  2850.293284
# 11  dataset2  GeneticNDSAlgorithm                20         300  5105.349877
# 12  dataset2  GeneticNDSAlgorithm                30         100  1956.157222
# 13  dataset2  GeneticNDSAlgorithm                30         200  3120.217519
# 14  dataset2  GeneticNDSAlgorithm                30         300  4650.112459
# 15  dataset2  GeneticNDSAlgorithm                40         100   778.497740
# 16  dataset2  GeneticNDSAlgorithm                40         200  3331.917745
# 17  dataset2  GeneticNDSAlgorithm                40         300  5957.658503
#
#                HV    Spread  AvgValue BestAvgValue BestGeneration  \
#              mean      mean      mean         mean           mean
# 9    85511.371071  0.857396  0.684216     0.763368      47.532143
# 10   95372.635357  0.871490  0.720296     0.835180      98.962500
# 11  103480.938879  0.878431  0.750346     0.891457     153.996383
# 12   91188.164286  0.834774  0.686490     0.767524      47.473214
# 13  105663.312747  0.865426  0.726142     0.845671     102.809695
# 14  113448.322121  0.871051  0.756743     0.903852     161.442413
# 15   90286.483571  0.851370  0.693305     0.779591      52.492857
# 16  107355.100179  0.859592  0.729871     0.852625     106.282648
# 17  114349.264493  0.867418  0.753706     0.898785     157.407609
#
#    NumSolutions   Spacing
#            mean      mean
# 9     35.437500  0.116389
# 10    40.589286  0.127630
# 11    43.616637  0.136934
# 12    37.442857  0.122811
# 13    44.201077  0.136916
# 14    47.868373  0.147340
# 15    38.741071  0.120611
# 16    45.191413  0.136956
# 17    48.413043  0.144391

# %% [markdown]
# ## Dataset 2-NSGA-II analysis

# %%
df_nsgaii2=summary[(summary['Dataset']=='dataset2') & (summary['Algorithm']=='NSGAIIAlgorithm')]
df_nsgaii2
# Out:
#      Dataset        Algorithm Population Length Generations      Time(s)  \
#                                                                     mean
# 45  dataset2  NSGAIIAlgorithm                20         100  6025.028530
# 46  dataset2  NSGAIIAlgorithm                20         200  5077.583080
# 47  dataset2  NSGAIIAlgorithm                20         300  7953.000213
# 48  dataset2  NSGAIIAlgorithm                30         100    62.017084
# 49  dataset2  NSGAIIAlgorithm                30         200   121.600667
# 50  dataset2  NSGAIIAlgorithm                30         300   182.440831
# 51  dataset2  NSGAIIAlgorithm                40         100    97.029399
# 52  dataset2  NSGAIIAlgorithm                40         200   192.436269
# 53  dataset2  NSGAIIAlgorithm                40         300   286.911602
#
#                HV    Spread  AvgValue BestAvgValue BestGeneration  \
#              mean      mean      mean         mean           mean
# 45   88739.242143  0.887150  0.631834     0.706855      60.166071
# 46  118762.555714  0.885022  0.640242     0.732192     126.105357
# 47  143744.893214  0.883727  0.643259     0.747373     189.273214
# 48   94322.902500  0.912505  0.644808     0.726443      65.516071
# 49  126268.139286  0.912753  0.656186     0.757664     131.791071
# 50  148390.860714  0.912345  0.664200     0.783660     202.853571
# 51  101068.022500  0.926218  0.650483     0.738916      68.800000
# 52  130187.889286  0.927311  0.668524     0.779243     138.292857
# 53  153655.117143  0.928062  0.678051     0.807650     211.257143
#
#    NumSolutions   Spacing
#            mean      mean
# 45    18.619643  0.146417
# 46    18.676786  0.167838
# 47    18.641071  0.184185
# 48    26.844643  0.145068
# 49    27.166071  0.167956
# 50    27.133929  0.180195
# 51    33.203571  0.146683
# 52    34.501786  0.165728
# 53    34.828571  0.180097

# %% [markdown]
# ---
# # Best Average Value for NSGA-II

# %%
df_best1=df_nsgaii[(df_nsgaii["Population Length"]==40) & (df_nsgaii["Generations"]==300)]
df_best2=df_nsgaii2[(df_nsgaii2["Population Length"]==40) & (df_nsgaii2["Generations"]==300)]
df_best_algs=pd.concat([df_best1,df_best2])
display(df_best_algs)
# Out:
#      Dataset        Algorithm Population Length Generations      Time(s)  \
#                                                                     mean
# 26  dataset1  NSGAIIAlgorithm                40         300  1305.592318
# 53  dataset2  NSGAIIAlgorithm                40         300   286.911602
#
#                HV    Spread  AvgValue BestAvgValue BestGeneration  \
#              mean      mean      mean         mean           mean
# 26   12266.417500  0.922011  3.972026     7.103189     158.691071
# 53  153655.117143  0.928062  0.678051     0.807650     211.257143
#
#    NumSolutions   Spacing
#            mean      mean
# 26    28.887500  0.373686
# 53    34.828571  0.180097

# %%
df_best_conf=df_alg[(df_alg["Population Length"]==40) & (df_alg["Generations"]==300)&(df_alg['Algorithm']=='NSGAIIAlgorithm')]
summary2=(
df_best_conf.groupby(['Crossover Probability','Mutation Probability'])
    [['Time(s)', 'HV', 'Spread',"AvgValue","BestAvgValue","BestGeneration","NumSolutions","Spacing"]]
    .agg(mean_time=('Time(s)', 'mean'),
         mean_hv=('HV', 'mean'),
         mean_spread=('Spread', 'mean'),
         mean_avgvalue=('AvgValue', 'mean'),
         mean_bestavgvalue=('BestAvgValue', 'mean'),
         mean_bestgeneration=('BestGeneration', 'mean'),
         mean_numsolutions=('NumSolutions', 'mean'),
         mean_spacing=('Spacing', 'mean'),
        )
    .reset_index()
    .sort_values("mean_avgvalue",ascending=False)
)
summary2
# Out:
#     Crossover Probability  Mutation Probability    mean_time     mean_hv  \
# 2                    0.60                  0.10   174.239250   91474.390
# 3                    0.60                  0.20   181.118064   91511.490
# 1                    0.60                  0.05   172.494968  108008.500
# 8                    0.80                  0.05   176.100636   88818.440
# 17                   0.85                  0.20   183.439277   64872.290
# 9                    0.80                  0.10  2637.345098   79107.605
# 10                   0.80                  0.20  2647.089455   72462.350
# 16                   0.85                  0.10   179.180016   68472.045
# 15                   0.85                  0.05   185.028591   78527.635
# 23                   0.90                  0.10   183.215581   63424.310
# 22                   0.90                  0.05   176.903119   71630.920
# 24                   0.90                  0.20   183.798803   61426.785
# 13                   0.80                  1.00  2654.669742  118314.150
# 4                    0.60                  0.50   183.226860  119083.545
# 12                   0.80                  0.70  2655.740140   99520.390
# 11                   0.80                  0.50  2646.686308   85495.910
# 18                   0.85                  0.50   183.100002   72894.115
# 19                   0.85                  0.70   181.496352   87558.300
# 5                    0.60                  0.70   180.825360  136950.415
# 6                    0.60                  1.00  2633.149423  149142.160
# 26                   0.90                  0.70   188.852152   74453.340
# 25                   0.90                  0.50   182.369039   66612.410
# 20                   0.85                  1.00   180.549599   96942.710
# 27                   0.90                  1.00   180.242429   83070.150
# 14                   0.85                  0.00   178.769888   46783.960
# 7                    0.80                  0.00  2639.595789   51815.975
# 21                   0.90                  0.00   178.951284   48633.120
# 0                    0.60                  0.00   166.877655   45894.075
#
#     mean_spread  mean_avgvalue  mean_bestavgvalue  mean_bestgeneration  \
# 2      0.930982       2.504118           4.485897              208.975
# 3      0.928537       2.459590           4.507658              208.475
# 1      0.930975       2.427991           4.374330              196.125
# 8      0.930562       2.427375           4.273584              197.075
# 17     0.926993       2.409538           4.188422              222.050
# 9      0.930984       2.406198           4.156164              209.650
# 10     0.926054       2.391638           4.231283              229.500
# 16     0.930058       2.382404           4.112009              207.625
# 15     0.930295       2.377364           4.106330              222.825
# 23     0.929537       2.375877           4.037494              230.150
# 22     0.929935       2.357476           3.978630              193.800
# 24     0.924078       2.338520           3.829147              208.325
# 13     0.924626       2.335691           4.002270              147.550
# 4      0.916468       2.329553           3.902415              157.525
# 12     0.916370       2.327700           4.097278              173.850
# 11     0.917383       2.326949           3.927739              205.750
# 18     0.917578       2.326299           4.056420              207.975
# 19     0.917067       2.325190           4.081352              183.875
# 5      0.918979       2.324221           4.103233              146.500
# 6      0.924292       2.316918           4.061595              139.200
# 26     0.918980       2.305778           4.021077              178.050
# 25     0.915018       2.301373           3.854690              192.525
# 20     0.927104       2.294443           4.078236              173.800
# 27     0.926554       2.287829           3.961592              167.850
# 14     0.927482       2.129582           3.259313              142.825
# 7      0.927781       2.127511           3.100069              125.625
# 21     0.927964       2.099207           3.032094              137.750
# 0      0.928386       2.084734           2.931421              164.050
#
#     mean_numsolutions  mean_spacing
# 2              31.925      0.310009
# 3              33.650      0.300730
# 1              31.000      0.311784
# 8              30.900      0.295437
# 17             33.750      0.258574
# 9              32.175      0.297827
# 10             33.725      0.270535
# 16             32.250      0.275208
# 15             31.300      0.283306
# 23             32.225      0.267728
# 22             31.525      0.274130
# 24             32.050      0.248189
# 13             33.850      0.307931
# 4              33.325      0.291275
# 12             33.550      0.286872
# 11             33.200      0.275305
# 18             33.175      0.266936
# 19             33.725      0.274220
# 5              34.275      0.305731
# 6              33.700      0.319617
# 26             34.225      0.265585
# 25             32.500      0.255207
# 20             33.775      0.314867
# 27             34.125      0.297540
# 14             25.325      0.220799
# 7              25.650      0.229662
# 21             26.575      0.227239
# 0              24.575      0.220720

# %% [markdown]
# # Best Average Value for GeneticNDS

# %%
df_best_conf=df_alg[(df_alg["Population Length"]==40) & (df_alg["Generations"]==300)&(df_alg['Algorithm']=='GeneticNDSAlgorithm')]
summary3=(
df_best_conf.groupby(['Crossover Probability','Mutation Probability'])
    [['Time(s)', 'HV', 'Spread',"AvgValue","BestAvgValue","BestGeneration","NumSolutions","Spacing"]]
    .agg(mean_time=('Time(s)', 'mean'),
         mean_hv=('HV', 'mean'),
         mean_spread=('Spread', 'mean'),
         mean_avgvalue=('AvgValue', 'mean'),
         mean_bestavgvalue=('BestAvgValue', 'mean'),
         mean_bestgeneration=('BestGeneration', 'mean'),
         mean_numsolutions=('NumSolutions', 'mean'),
         mean_spacing=('Spacing', 'mean'),
        )
    .reset_index()
    .sort_values("mean_avgvalue",ascending=False)
)
summary3
# Out:
#     Crossover Probability  Mutation Probability     mean_time       mean_hv  \
# 0                    0.60                  0.00  41065.907525  43315.311765
# 14                   0.85                  0.00   2730.381871  53454.870000
# 7                    0.80                  0.00   4946.462192  60604.630000
# 3                    0.60                  0.20   2464.852453  68841.142500
# 15                   0.85                  0.05    532.217850  53256.712500
# 8                    0.80                  0.05    681.139919  48286.605000
# 1                    0.60                  0.05  10177.673357  55965.070000
# 21                   0.90                  0.00   3243.566095  56305.690000
# 16                   0.85                  0.10    716.097013  61415.387500
# 2                    0.60                  0.10   7787.822235  58149.310000
# 22                   0.90                  0.05    299.024931  51402.402500
# 10                   0.80                  0.20    582.192522  62550.130000
# 17                   0.85                  0.20    207.877408  63668.735000
# 9                    0.80                  0.10   1753.586236  62625.950000
# 23                   0.90                  0.10    223.647941  53928.940000
# 24                   0.90                  0.20    176.754673  56942.730000
# 4                    0.60                  0.50    251.520233  74313.677500
# 11                   0.80                  0.50    184.679253  64932.232500
# 25                   0.90                  0.50    118.934218  65163.055000
# 18                   0.85                  0.50    154.354513  59146.450000
# 26                   0.90                  0.70   4999.007824  62780.007500
# 12                   0.80                  0.70    121.239706  63489.230000
# 6                    0.60                  1.00    136.425285  62633.690000
# 5                    0.60                  0.70    135.813176  60810.885000
# 19                   0.85                  0.70    105.805609  59777.715000
# 13                   0.80                  1.00     97.320578  61054.240000
# 20                   0.85                  1.00     94.810853  58104.987500
# 27                   0.90                  1.00   4989.680500  58495.632500
#
#     mean_spread  mean_avgvalue  mean_bestavgvalue  mean_bestgeneration  \
# 0      1.141119       3.424128           3.660328           109.132353
# 14     1.137620       3.115573           3.428303           117.500000
# 7      1.152929       3.024515           3.295405            92.312500
# 3      0.886904       2.935284           3.777414           149.250000
# 15     0.890443       2.865471           3.743563           119.712500
# 8      0.901901       2.855079           3.575295           134.712500
# 1      0.912600       2.844105           3.656339           142.850000
# 21     1.060718       2.836931           3.158366           108.887500
# 16     0.849111       2.825058           3.639657           152.125000
# 2      0.891381       2.811023           3.674815           130.487500
# 22     0.841011       2.752462           3.929518           152.712500
# 10     0.838804       2.710338           3.627588           168.312500
# 17     0.799520       2.706851           3.656053           146.762500
# 9      0.851946       2.691006           3.566344           147.400000
# 23     0.833748       2.673070           3.602078           152.100000
# 24     0.793361       2.665474           3.687563           161.137500
# 4      0.804567       2.571936           3.624766           151.375000
# 11     0.788539       2.560867           3.619369           151.737500
# 25     0.710107       2.368504           3.538423           146.087500
# 18     0.730977       2.354552           3.655617           166.212500
# 26     0.695294       2.276796           3.353661           151.412500
# 12     0.739455       2.224996           3.314035           165.475000
# 6      0.791733       2.221268           3.308240           147.900000
# 5      0.778905       2.217408           3.413269           159.637500
# 19     0.718597       2.204258           3.414550           149.612500
# 13     0.719511       2.198251           3.292770           158.562500
# 20     0.703256       2.169428           3.273935           163.550000
# 27     0.690538       2.155889           3.339901           170.087500
#
#     mean_numsolutions  mean_spacing
# 0           39.235294      0.149095
# 14          37.800000      0.198392
# 7           40.237500      0.144513
# 3           43.375000      0.270941
# 15          38.487500      0.220645
# 8           35.887500      0.231211
# 1           40.600000      0.216935
# 21          41.650000      0.188502
# 16          39.025000      0.240436
# 2           44.200000      0.222489
# 22          39.450000      0.238418
# 10          42.912500      0.241564
# 17          39.537500      0.260341
# 9           39.237500      0.228081
# 23          39.237500      0.227178
# 24          38.950000      0.243650
# 4           46.100000      0.261318
# 11          43.900000      0.259099
# 25          43.312500      0.246851
# 18          42.200000      0.271642
# 26          41.275000      0.232050
# 12          41.662500      0.230557
# 6           41.650000      0.227221
# 5           39.825000      0.221470
# 19          41.400000      0.222024
# 13          38.900000      0.218086
# 20          40.350000      0.218665
# 27          37.987500      0.208117

# %% [markdown]
# ## NSGA-II 300Gener;40PopLen;0.85CrossProb;0.1MutProb - orange
# ## GeneticNDS 300Gener;40PopLen;0.85CrossProb;0.05MutProb - blue
# <img src="output/images/Figure_2.png">

# %%
df_radar = df_alg.copy(deep=True)

#df_radar[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']]=df_radar[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

#dividir por algoritmo y dataset
df_star_d1_gnds=df_radar[(df_radar['Algorithm']=='GeneticNDSAlgorithm')&(df_radar['Dataset']=='dataset1')]
df_star_d2_gnds=df_radar[(df_radar['Algorithm']=='GeneticNDSAlgorithm')&(df_radar['Dataset']=='dataset2')]
df_star_d1_nsgaii=df_radar[(df_radar['Algorithm']=='NSGAIIAlgorithm')&(df_radar['Dataset']=='dataset1')]
df_star_d2_nsgaii=df_radar[(df_radar['Algorithm']=='NSGAIIAlgorithm')&(df_radar['Dataset']=='dataset2')]

#calcular la media
df_star_d1_gnds_means=df_star_d1_gnds[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d2_gnds_means=df_star_d2_gnds[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d1_nsgaii_means=df_star_d1_nsgaii[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d2_nsgaii_means=df_star_d2_nsgaii[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()

display(df_star_d1_gnds_means)
display(df_star_d1_nsgaii_means)
display(df_star_d2_gnds_means)
display(df_star_d2_nsgaii_means)
print("-----------------\n")


#invertir los valores que son mejores cuanto menores son
#df_radar['Time(s)']=(1/df_radar['Time(s)'])*1000
#df_radar['Spread']=(1/df_radar['Spread'])

df_star_d1_gnds=df_radar[(df_radar['Algorithm']=='GeneticNDSAlgorithm')&(df_radar['Dataset']=='dataset1')]
df_star_d2_gnds=df_radar[(df_radar['Algorithm']=='GeneticNDSAlgorithm')&(df_radar['Dataset']=='dataset2')]
df_star_d1_nsgaii=df_radar[(df_radar['Algorithm']=='NSGAIIAlgorithm')&(df_radar['Dataset']=='dataset1')]
df_star_d2_nsgaii=df_radar[(df_radar['Algorithm']=='NSGAIIAlgorithm')&(df_radar['Dataset']=='dataset2')]

df_star_d1_gnds_means=df_star_d1_gnds[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d2_gnds_means=df_star_d2_gnds[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d1_nsgaii_means=df_star_d1_nsgaii[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d2_nsgaii_means=df_star_d2_nsgaii[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()

display(df_star_d1_gnds_means)
display(df_star_d1_nsgaii_means)
display(df_star_d2_gnds_means)
display(df_star_d2_nsgaii_means)
print("-----------------\n")

#normalizar valores
#min_max_scaler = preprocessing.MinMaxScaler()
# Create an object to transform the data to fit minmax processor
df_radar['HV'] = min_max_scaler.fit_transform(df_radar[['HV']].values.astype(float))
df_radar['Spread'] = min_max_scaler.fit_transform(df_radar[['Spread']].values.astype(float))
df_radar['Spacing'] = min_max_scaler.fit_transform(df_radar[['Spacing']].values.astype(float))
df_radar['NumSolutions'] = min_max_scaler.fit_transform(df_radar[['NumSolutions']].values.astype(float))
df_radar['AvgValue'] = min_max_scaler.fit_transform(df_radar[['AvgValue']].values.astype(float))
df_radar['Time(s)'] = min_max_scaler.fit_transform(df_radar[['Time(s)']].values.astype(float))

#df_radar['HV'] = np.log10(df_radar[['HV']].values.astype(float))
#df_radar['Spread'] = np.log10(df_radar[['Spread']].values.astype(float))
#df_radar['Spacing'] = np.log10(df_radar[['Spacing']].values.astype(float))
#df_radar['NumSolutions'] = np.log10(df_radar[['NumSolutions']].values.astype(float))
#df_radar['AvgValue'] = np.log10(df_radar[['AvgValue']].values.astype(float))
#df_radar['Time(s)'] = np.log10(df_radar[['Time(s)']].values.astype(float))

#df_radar['Time(s)']=(1/df_radar['Time(s)'])
#df_radar['Spread']=(1/df_radar['Spread'])

#dividir por algoritmo y dataset
df_star_d1_gnds=df_radar[(df_radar['Algorithm']=='GeneticNDSAlgorithm')&(df_radar['Dataset']=='dataset1')]
df_star_d2_gnds=df_radar[(df_radar['Algorithm']=='GeneticNDSAlgorithm')&(df_radar['Dataset']=='dataset2')]
df_star_d1_nsgaii=df_radar[(df_radar['Algorithm']=='NSGAIIAlgorithm')&(df_radar['Dataset']=='dataset1')]
df_star_d2_nsgaii=df_radar[(df_radar['Algorithm']=='NSGAIIAlgorithm')&(df_radar['Dataset']=='dataset2')]
#calcular la media
df_star_d1_gnds_means=df_star_d1_gnds[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d2_gnds_means=df_star_d2_gnds[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d1_nsgaii_means=df_star_d1_nsgaii[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d2_nsgaii_means=df_star_d2_nsgaii[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()

display(df_star_d1_gnds_means)
display(df_star_d1_nsgaii_means)
display(df_star_d2_gnds_means)
display(df_star_d2_nsgaii_means)
# Out:
# HV              10078.499008
# Spread              0.822102
# Spacing             0.310662
# NumSolutions       30.102083
# AvgValue            4.289387
# Time(s)           721.492490
# dtype: float64
# HV              11016.870516
# Spread              0.896219
# Spacing             0.345779
# NumSolutions       23.487302
# AvgValue            3.734450
# Time(s)           285.726907
# dtype: float64
# HV              96835.257553
# Spread              0.844908
# Spacing             0.124703
# NumSolutions       42.134516
# AvgValue            0.695921
# Time(s)          2474.488569
# dtype: float64
# HV              122793.291389
# Spread               0.908344
# Spacing              0.164907
# NumSolutions        26.624008
# AvgValue             0.653065
# Time(s)           2222.005297
# dtype: float64
# -----------------
# HV              10078.499008
# Spread              0.822102
# Spacing             0.310662
# NumSolutions       30.102083
# AvgValue            4.289387
# Time(s)           721.492490
# dtype: float64
# HV              11016.870516
# Spread              0.896219
# Spacing             0.345779
# NumSolutions       23.487302
# AvgValue            3.734450
# Time(s)           285.726907
# dtype: float64
# HV              96835.257553
# Spread              0.844908
# Spacing             0.124703
# NumSolutions       42.134516
# AvgValue            0.695921
# Time(s)          2474.488569
# dtype: float64
# HV              122793.291389
# Spread               0.908344
# Spacing              0.164907
# NumSolutions        26.624008
# AvgValue             0.653065
# Time(s)           2222.005297
# dtype: float64
# -----------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-eec78637ed71> in <module>
#      45 #min_max_scaler = preprocessing.MinMaxScaler()
#      46 # Create an object to transform the data to fit minmax processor
# ---> 47 df_radar['HV'] = min_max_scaler.fit_transform(df_radar[['HV']].values.astype(float))
#      48 df_radar['Spread'] = min_max_scaler.fit_transform(df_radar[['Spread']].values.astype(float))
#      49 df_radar['Spacing'] = min_max_scaler.fit_transform(df_radar[['Spacing']].values.astype(float))
#
# NameError: name 'min_max_scaler' is not defined

# %%
#HACER PRIMERO ESCALADO POR DATASET, LUEGO AGRUPAR POR ALGORITMO, LUEGO CALCULAR MEDIA POR ALGORITMO-DATASET

df_radar = df_alg.copy(deep=True)

#dividir por algoritmo y dataset
df_star_d1_gnds=df_radar[(df_radar['Algorithm']=='GeneticNDSAlgorithm')&(df_radar['Dataset']=='dataset1')]
df_star_d2_gnds=df_radar[(df_radar['Algorithm']=='GeneticNDSAlgorithm')&(df_radar['Dataset']=='dataset2')]
df_star_d1_nsgaii=df_radar[(df_radar['Algorithm']=='NSGAIIAlgorithm')&(df_radar['Dataset']=='dataset1')]
df_star_d2_nsgaii=df_radar[(df_radar['Algorithm']=='NSGAIIAlgorithm')&(df_radar['Dataset']=='dataset2')]

df_dataset1=df_radar[(df_radar['Dataset']=='dataset1')]
df_dataset2=df_radar[(df_radar['Dataset']=='dataset2')]

#normalizar valores
min_max_scaler = preprocessing.MinMaxScaler()
df_dataset1['HV'] = min_max_scaler.fit_transform(df_dataset1[['HV']].values.astype(float))
df_dataset1['Spread'] = min_max_scaler.fit_transform(df_dataset1[['Spread']].values.astype(float))
df_dataset1['Spacing'] = min_max_scaler.fit_transform(df_dataset1[['Spacing']].values.astype(float))
df_dataset1['NumSolutions'] = min_max_scaler.fit_transform(df_dataset1[['NumSolutions']].values.astype(float))
df_dataset1['AvgValue'] = min_max_scaler.fit_transform(df_dataset1[['AvgValue']].values.astype(float))
df_dataset1['Time(s)'] = min_max_scaler.fit_transform(df_dataset1[['Time(s)']].values.astype(float))

df_dataset2['HV'] = min_max_scaler.fit_transform(df_dataset2[['HV']].values.astype(float))
df_dataset2['Spread'] = min_max_scaler.fit_transform(df_dataset2[['Spread']].values.astype(float))
df_dataset2['Spacing'] = min_max_scaler.fit_transform(df_dataset2[['Spacing']].values.astype(float))
df_dataset2['NumSolutions'] = min_max_scaler.fit_transform(df_dataset2[['NumSolutions']].values.astype(float))
df_dataset2['AvgValue'] = min_max_scaler.fit_transform(df_dataset2[['AvgValue']].values.astype(float))
df_dataset2['Time(s)'] = min_max_scaler.fit_transform(df_dataset2[['Time(s)']].values.astype(float))

df_star_d1_gnds=df_dataset1[(df_dataset1['Algorithm']=='GeneticNDSAlgorithm')]
df_star_d1_nsgaii=df_dataset1[(df_dataset1['Algorithm']=='NSGAIIAlgorithm')]
df_star_d2_gnds=df_dataset2[(df_dataset2['Algorithm']=='GeneticNDSAlgorithm')]
df_star_d2_nsgaii=df_dataset2[(df_dataset2['Algorithm']=='NSGAIIAlgorithm')]
                             
df_star_d1_gnds_means=df_star_d1_gnds[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d2_gnds_means=df_star_d2_gnds[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d1_nsgaii_means=df_star_d1_nsgaii[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
df_star_d2_nsgaii_means=df_star_d2_nsgaii[['HV','Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']].mean()
                             
display(df_star_d1_gnds_means)
display(df_star_d1_nsgaii_means)
display(df_star_d2_gnds_means)
display(df_star_d2_nsgaii_means)

# %%
sns.set()

labels=np.array(['HV', 'Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)'])

#stats=df.loc[1,labels].values
stats=df_star_d1_gnds_means

angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# close the plot
stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))
fig=plt.figure()
ax = fig.add_subplot(111, polar=True)
ax.plot(angles, stats, 'o-', linewidth=2)
ax.fill(angles, stats, alpha=0.25)
#ax.set_thetagrids(angles * 180/np.pi, labels)
ax.set_title("Dataset 1")
ax.set_xlabels(['HV', 'Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)'])
ax.grid(True)

# %%
print(list(df_star_d1_gnds_means))
import plotly.express as px
df = pd.DataFrame(dict(
    r=list(df_star_d1_gnds_means),
    theta=['HV', 'Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']))
fig = px.line_polar(df, r='r', theta='theta', line_close=True)
fig.show()

# %%
import plotly.graph_objects as go
import plotly.offline as pyo


categories = ['HV', 'Spread', 'Spacing', 'NumSolutions', 'AvgValue', 'Time(s)']
categories = [*categories, categories[0]]

data_1 = list(df_star_d1_gnds_means)
data_2 = list(df_star_d1_nsgaii_means)
#data_3 = list(df_star_d2_gnds_means)
#data_4 = list(df_star_d2_nsgaii_means)

data_1 = [*data_1, data_1[0]]
data_2 = [*data_2, data_2[0]]
data_3 = [*data_3, data_3[0]]
data_4 = [*data_4, data_4[0]]


fig = go.Figure(
    data=[
        go.Scatterpolar(r=data_1, theta=categories, name='D1-GeneticNDS'),
        go.Scatterpolar(r=data_2, theta=categories, name='D1-NSGAII'),
        #go.Scatterpolar(r=data_3, theta=categories, name='D2-GeneticNDS'),
        #go.Scatterpolar(r=data_4, theta=categories, name='D2-NSGAII'),
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Algorithm comparison'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig)

# %%
fig2 = go.Figure(
    data=[
        #go.Scatterpolar(r=data_1, theta=categories, name='D1-GeneticNDS'),
        #go.Scatterpolar(r=data_2, theta=categories, name='D1-NSGAII'),
        go.Scatterpolar(r=data_3, theta=categories, name='D2-GeneticNDS'),
        go.Scatterpolar(r=data_4, theta=categories, name='D2-NSGAII'),
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Algorithm comparison'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig2)

# %%
df_best_conf=df_alg[(df_alg["Population Length"]==40) & (df_alg["Generations"]==300)&(df_alg['Algorithm']=='NSGAIIAlgorithm')&(df_alg['Dataset']=='dataset1')]
summary2=(
df_best_conf.groupby(['Crossover Probability','Mutation Probability'])
    [['Time(s)', 'HV', 'Spread',"AvgValue","BestAvgValue","BestGeneration","NumSolutions","Spacing"]]
    .agg(mean_time=('Time(s)', 'mean'),
         mean_hv=('HV', 'mean'),
         mean_spread=('Spread', 'mean'),
         mean_avgvalue=('AvgValue', 'mean'),
         mean_bestavgvalue=('BestAvgValue', 'mean'),
         mean_bestgeneration=('BestGeneration', 'mean'),
         mean_numsolutions=('NumSolutions', 'mean'),
         mean_spacing=('Spacing', 'mean'),
        )
    .reset_index()
    .sort_values("mean_avgvalue",ascending=False)
)
summary2

# %%
df_nsgaii=df_alg[df_alg['Algorithm']=='NSGAIIAlgorithm']
df_nsgaii=df_nsgaii[["Population Length","Generations","Time(s)","HV","Spread","AvgValue","BestAvgValue","BestGeneration","NumSolutions","Spacing"]]
summary = (df_nsgaii.groupby(['Population Length', 'Generations'])
                 [['Time(s)', 'HV', 'Spread',"AvgValue","BestAvgValue","BestGeneration","NumSolutions","Spacing"]]
                 .agg(['mean'])
                 .reset_index()
          )
summary

# %%
display(df_alg[df_alg["Replacement Scheme"]=="elitismnds"])

# %%
'''
index=summary.index
plt.scatter(summary)
plt.legend(summary.columns)
'''

# %%
#df_cleared=df_alg[(df_alg["Algorithm"]=="GeneticAlgorithm") | (df_alg["Algorithm"]=="NSGAIIAlgorithm")]
#df_cleared.to_csv('output/experimento_2datasets_2_10.csv', sep=',')
